# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from visibility_graph import visibility_graph
import networkx as nx
import statsmodels.api as sm

# %%
def get_alpha(data,li_fit,ls_fit,xlimi,xlims):
    G = nx.read_edgelist(data, nodetype=int)
    # Calculate degree distribution
    degree_sequence = G.degree()#[G.degree(node) for node in G.nodes()]
    degree_count = nx.degree_histogram(G)
    degrees = range(len(degree_count))
    # Normalize the degree distribution
    degree_distribution = [count / float(sum(degree_count)) for count in degree_count]
    # Calcule alpha
    x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))
    x,y=x0[(x0>=li_fit)&(x0<=ls_fit)],y0[(x0>=li_fit)&(x0<=ls_fit)]
    x = sm.add_constant(x)
    model = sm.OLS(y, x).fit()
    predictions = model.predict(x) 
    print_model = model.summary()

    # Plot degree distribution
    plt.figure(figsize=(6,4))
    plt.plot(x0,y0,color="k",linewidth=0,marker="o",markersize=3,label="data")
    a=np.linspace(li_fit,ls_fit,10)
    plt.plot(a,(a)*(model.params[1])+model.params[0],color="r",label=r"fit ($\alpha_0={}$)".format(-np.round(model.params[1],2)))
    plt.xlabel(r'$\log_{10}(k)$ (Degree)'); plt.ylabel(r'$\log_{10} P(k)$'); plt.title('Degree Distribution'); plt.legend(); plt.xlim(xlimi,xlims)
    plt.legend(title=r"$P(k)\sim x^{-\alpha_0}$")
    plt.show()
    return x0,y0,li_fit,ls_fit,xlimi,xlims,np.round(model.params[0],2),np.round(model.params[1],2)

# %%
Moscow=get_alpha("Moscow_Count_day_vis_results",1.2,1.6,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))

# %%
Newark=get_alpha("Newark_Count_day_vis_results",1.1,1.45,0.75,2.4)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
Novosibirsk=get_alpha("Novosibirsk_Count_day_vis_results",1.1,1.5,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
Oulu=get_alpha("Oulu_Count_day_vis_results",1.2,1.545,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))

# %%
Rome=get_alpha("Rome_Count_day_vis_results",1.2,1.55,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))

# %%
Thule=get_alpha("Thule_Count_day_vis_results",1.2,1.55,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))

# %%
Yakutsk=get_alpha("Yakutsk_Count_day_vis_results",1.1,1.55,0.75,2.0)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))

# %%
Lomnicky=get_alpha("Lomnicky_Count_day_vis_results",1.1,1.45,0.75,2.0)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
Irkutsk2000=get_alpha("Irkutsk2000_Count_day_vis_results",1.2,1.55,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))

# %%
Inuvik=get_alpha("Inuvik_Count_day_vis_results",1.2,1.55,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))

# %%
FortSmith=get_alpha("FortSmith_Count_day_vis_results",1.2,1.55,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))

# %%
Esoi=get_alpha("Esoi_Count_day_vis_results",1.1,1.55,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))

# %%
Athens=get_alpha("Athens_Count_day_vis_results",1.1,1.45,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
Apatity=get_alpha("Apatity_Count_day_vis_results",1.2,1.6,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))

# %%
Hermanus=get_alpha("Hermanus_Count_day_vis_results",1.1,1.45,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
Barentsburg=get_alpha("Barentsburg_Count_day_vis_results",1.1,1.45,0.75,2.2)
# Out:
# /tmp/ipykernel_19801/1247186930.py:10: RuntimeWarning: divide by zero encountered in log10
#   x0,y0=np.array(np.log10(degrees)),np.array(np.log10(degree_distribution))
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
results=[Moscow,Newark,Novosibirsk,Oulu,Rome,Thule,Yakutsk,Lomnicky,Irkutsk2000,Inuvik,FortSmith,Esoi,Athens,Apatity,Hermanus,Barentsburg]
names_results=["Moscow","Newark","Novosibirsk","Oulu","Rome","Thule","Yakutsk","Lomnicky","Irkutsk","Inuvik","FortSmith","Esoi","Athens","Apatity","Hermanus","Barentsburg"]
names_results2=["Mos","New","Nov","Oul","Rom","Thu","Yak","Lom","Irk","Inu","For","Eso","Ath","Apa","Her","Bar"]
alphas=[-results[i][-1] for i in range(len(results))]
rigidity=[2.43,2.4,2.91,0.8,6.27,0.3,1.65,3.84,3.64,0.3,0.3,10.75,8.53,0.65,4.58,0.01] # GV
altitude=[200,50,163,15,0,26,105,2634,2000,21,180,2055,260,181,26,51] # masl
latitude=[55.47,39.68,54.48,65.05,41.86,76.5,62.01,49.20,52.37,68.36,60.02,33.3,37.97,67.57,34.43,78.03] # N
longitude=[37.32,180-75.75,83,25.47,12.47,180-68.7,129.43,20.22,100.55,180-133.72,180-111.93,35.8,23.78,33.4,19.23,14.13] # E

# %%
plt.figure(figsize=(22,12))#plt.figure(figsize=(22,10))
for i in range(len(results)):
    if (i==0)|(i==4)|(i==8) :
        plt.subplot(4,4,i+1)
        plt.plot(results[i][0],results[i][1],color="k",linewidth=0,marker="o",markersize=3,label="data")
        a=np.linspace(results[i][2],results[i][3],10)
        plt.plot(a,(a)*(results[i][7])+results[i][6],color="r",label=r"fit ($\alpha_0={}$)".format(-results[i][7]))
        plt.ylabel(r'$\log_{10} P(k)$'); plt.legend(); plt.xlim(results[i][4],results[i][5]); #plt.title(names_results[i]+" station"); 
        plt.legend(title=r"$P(k)\sim x^{-\alpha_0},$ "+names_results[i]+" station")
    elif (i==13)|(i==14)|((i==15)) :
        plt.subplot(4,4,i+1)
        plt.plot(results[i][0],results[i][1],color="k",linewidth=0,marker="o",markersize=3,label="data")
        a=np.linspace(results[i][2],results[i][3],10)
        plt.plot(a,(a)*(results[i][7])+results[i][6],color="r",label=r"fit ($\alpha_0={}$)".format(-results[i][7]))
        plt.xlabel(r'$\log_{10}(k)$ (Degree)'); plt.legend(); plt.xlim(results[i][4],results[i][5]); #plt.title(names_results[i]+" station"); 
        plt.legend(title=r"$P(k)\sim x^{-\alpha_0},$ "+names_results[i]+" station")
    elif (i==12) :
        plt.subplot(4,4,i+1)
        plt.plot(results[i][0],results[i][1],color="k",linewidth=0,marker="o",markersize=3,label="data")
        a=np.linspace(results[i][2],results[i][3],10)
        plt.plot(a,(a)*(results[i][7])+results[i][6],color="r",label=r"fit ($\alpha_0={}$)".format(-results[i][7]))
        plt.ylabel(r'$\log_{10} P(k)$'); plt.xlabel(r'$\log_{10}(k)$ (Degree)'); plt.legend(); plt.xlim(results[i][4],results[i][5]); #plt.title(names_results[i]+" station"); 
        plt.legend(title=r"$P(k)\sim x^{-\alpha_0},$ "+names_results[i]+" station")
    else:
        plt.subplot(4,4,i+1)
        plt.plot(results[i][0],results[i][1],color="k",linewidth=0,marker="o",markersize=3,label="data")
        a=np.linspace(results[i][2],results[i][3],10)
        plt.plot(a,(a)*(results[i][7])+results[i][6],color="r",label=r"fit ($\alpha_0={}$)".format(-results[i][7]))
        plt.legend(); plt.xlim(results[i][4],results[i][5]); #plt.title(names_results[i]+" station"); 
        plt.legend(title=r"$P(k)\sim x^{-\alpha_0},$ "+names_results[i]+" station")
plt.savefig("visibility_results16.pdf",dpi=400,bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(13,4))
plt.subplot(121)
plt.plot(rigidity,alphas,linewidth=0,marker="o",markerfacecolor="w",markeredgewidth=2,markersize=5,c="k")
plt.xlabel("Rigidity Cutoff (GV)"); plt.ylabel(r"Slope: $\alpha_0$");plt.xlim(0.0,12);
#for i in range(len(rigidity)):
#    plt.text(rigidity[i]+0.15,alphas[i],names_results2[i],ha="left",va="center",fontsize=9)
#plt.xticks(np.arange(0.6,3.1,0.2)); plt.yticks(np.arange(2.7,3.5,0.1))
plt.subplot(122)
plt.plot(latitude,alphas,linewidth=0,marker="o",markerfacecolor="w",markeredgewidth=2,markersize=5,c="k")
plt.xlabel("Latitude (North)"); plt.ylabel(r"Slope: $\alpha_0$");#plt.xlim(0.0,12);
#for i in range(len(rigidity)):
#    plt.text(rigidity[i]+0.15,alphas[i],names_results2[i],ha="left",va="center",fontsize=9)
#plt.xticks(np.arange(0.6,3.1,0.2)); plt.yticks(np.arange(2.7,3.5,0.1))
plt.show()

# %%
x1,y1=rigidity,alphas
x1 = sm.add_constant(x1)
model1 = sm.OLS(y1, x1).fit()
print_model1 = model1.summary()
print_model1
# Out:
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.650
# Model:                            OLS   Adj. R-squared:                  0.625
# Method:                 Least Squares   F-statistic:                     25.98
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):           0.000163
# Time:                        09:33:33   Log-Likelihood:                 13.388
# No. Observations:                  16   AIC:                            -22.78
# Df Residuals:                      14   BIC:                            -21.23
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
x2,y1=latitude,alphas
x2 = sm.add_constant(x2)
model2 = sm.OLS(y1, x2).fit()
print_model2 = model2.summary()
print_model2
# Out:
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.649
# Model:                            OLS   Adj. R-squared:                  0.624
# Method:                 Least Squares   F-statistic:                     25.86
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):           0.000166
# Time:                        09:33:33   Log-Likelihood:                 13.364
# No. Observations:                  16   AIC:                            -22.73
# Df Residuals:                      14   BIC:                            -21.18
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
model1.bse[0]
# Out:
# 0.03986088281413028

# %%
plt.figure(figsize=(15,3))
plt.subplot(121)
r=np.arange(0,13,3)
plt.plot(rigidity,alphas,linewidth=0,marker="o",markerfacecolor="w",markeredgewidth=2,markersize=5,c="k",label="data")
plt.plot(r,model1.params[1]*r+model1.params[0],c="r",label=r"fit $R_c=({}\pm{})\alpha_0+({}\pm{})$".format(model1.params[1].round(3),
                                                                                                          model1.bse[1].round(3),
                                                                                                           model1.params[0].round(3),
                                                                                                           model1.bse[0].round(3)))
plt.legend(fontsize=9)
plt.xlabel("Rigidity Cutoff (GV)"); plt.ylabel(r"Slope: $\alpha_0$");#plt.xlim(-1.,12.5);plt.ylim(0.9,1.23);
for i in range(len(rigidity)):
    plt.text(rigidity[i]+0.25,alphas[i],names_results2[i],ha="left",va="center",fontsize=9,color="DarkBlue")
#plt.xticks(np.arange(-0.5,12.1,1.)); plt.yticks(np.arange(0.9,1.26,0.05))
plt.subplot(122)
l=np.arange(30,83,3)
plt.plot(latitude,alphas,linewidth=0,marker="o",markerfacecolor="w",markeredgewidth=2,markersize=5,c="k",label="data")
plt.plot(l,model2.params[1]*l+model2.params[0],c="r",label=r"fit $R_c=({}\pm{})\alpha_0+({}\pm{})$".format(model2.params[1].round(3),
                                                                                                          model2.bse[1].round(3),
                                                                                                           model2.params[0].round(3),
                                                                                                           model2.bse[0].round(3)))
plt.legend(fontsize=9)
plt.xlabel("Latitude (North)"); plt.ylabel(r"Slope: $\alpha_0$");#plt.xlim(25,85);plt.ylim(0.95,1.27);
for i in range(len(rigidity)):
    plt.text(latitude[i]-0.8,alphas[i],names_results2[i],ha="right",va="center",fontsize=9,color="DarkBlue")
#plt.xticks(np.arange(25,85.1,5.)); plt.yticks(np.arange(0.9,1.26,0.05))
plt.savefig("visibility_regre.pdf",dpi=400,bbox_inches="tight")
plt.show()

# %%
neutrons=pd.DataFrame()
neutrons.index=names_results
neutrons["Lat (N)"],neutrons["lon (E)"],neutrons["Alt. (masl)"],neutrons["Rigidity (GV)"]=latitude, longitude, altitude, rigidity

# %%
neutrons.T
# Out:
#                Moscow  Newark  Novosibirsk   Oulu   Rome  Thule  Yakutsk
# Lat (N)         55.47   39.68        54.48  65.05  41.86   76.5    62.01  \
# lon (E)         37.32  104.25        83.00  25.47  12.47  111.3   129.43
# Alt. (masl)    200.00   50.00       163.00  15.00   0.00   26.0   105.00
# Rigidity (GV)    2.43    2.40         2.91   0.80   6.27    0.3     1.65
#
#                Lomnicky  Irkutsk  Inuvik  FortSmith     Esoi  Athens  Apatity
# Lat (N)           49.20    52.37   68.36      60.02    33.30   37.97    67.57  \
# lon (E)           20.22   100.55   46.28      68.07    35.80   23.78    33.40
# Alt. (masl)     2634.00  2000.00   21.00     180.00  2055.00  260.00   181.00
# Rigidity (GV)      3.84     3.64    0.30       0.30    10.75    8.53     0.65
#
#                Hermanus  Barentsburg
# Lat (N)           34.43        78.03
# lon (E)           19.23        14.13
# Alt. (masl)       26.00        51.00
# Rigidity (GV)      4.58         0.01

# %%
model1.params[1], model1.bse[1].round(3), model1.params[0], model1.bse[0].round(3)
# Out:
# (-0.04685854603138703, 0.009, 3.152683614506829, 0.04)
